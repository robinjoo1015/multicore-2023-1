# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
exec_time_list = np.zeros((4, 9, 10), dtype=np.float64)

# %%
for sched_idx, scheduling_type in enumerate(range(1,5)):
    for thread_idx, num_of_thread in enumerate([1,2,4,6,8,10,12,14,16]):
        print(scheduling_type, num_of_thread)
        for repeat in range(10):
            output = ! ./a.out {scheduling_type} {num_of_thread}
            exec_time_list[sched_idx, thread_idx, repeat] = float(output[0].split(':')[1].split('ms')[0].strip())
# Out:
# 1 1
# 1 2
# 1 4
# 1 6
# 1 8
# 1 10
# 1 12
# 1 14
# 1 16
# 2 1
# 2 2
# 2 4
# 2 6
# 2 8
# 2 10
# 2 12
# 2 14
# 2 16
# 3 1
# 3 2
# 3 4
# 3 6
# 3 8
# 3 10
# 3 12
# 3 14
# 3 16
# 4 1
# 4 2
# 4 4
# 4 6
# 4 8
# 4 10
# 4 12
# 4 14
# 4 16

# %%
exec_time_list
# Out:
# array([[[2022.701, 2030.465, 2043.059, 2048.71 , 2032.405, 2020.849,
#          2042.589, 2033.57 , 2029.522, 2033.033],
#         [1501.483, 1496.249, 1495.527, 1497.114, 1493.387, 1499.9  ,
#          1499.335, 1493.999, 1502.733, 1491.739],
#         [ 885.259,  886.055,  884.061,  883.748,  883.05 ,  892.072,
#           900.307,  887.784,  886.489,  907.407],
#         [ 678.96 ,  659.194,  663.001,  661.15 ,  665.607,  659.627,
#           665.079,  681.987,  657.829,  675.293],
#         [ 586.898,  552.38 ,  564.91 ,  571.824,  555.865,  562.68 ,
#           551.593,  553.217,  550.906,  553.871],
#         [ 504.327,  496.34 ,  496.682,  485.906,  478.359,  478.722,
#           491.164,  492.563,  501.994,  504.284],
#         [ 471.969,  442.314,  524.214,  465.54 ,  446.031,  463.477,
#           466.087,  482.88 ,  535.162,  455.689],
#         [ 447.685,  454.296,  448.719,  459.384,  473.548,  453.034,
#           454.361,  439.801,  437.766,  467.114],
#         [ 434.913,  439.346,  443.582,  445.054,  500.27 ,  446.58 ,
#           431.038,  443.32 ,  437.538,  447.667]],
#
#        [[2038.454, 2025.257, 2023.359, 2023.501, 2018.913, 2021.976,
#          2022.031, 2024.432, 2020.607, 2022.634],
#         [1034.531, 1035.117, 1037.799, 1034.226, 1037.612, 1036.511,
#          1037.392, 1036.408, 1037.159, 1040.304],
#         [ 536.107,  537.699,  536.875,  541.63 ,  536.398,  537.526,
#           535.81 ,  542.928,  538.539,  537.133],
#         [ 452.119,  452.445,  456.655,  452.107,  453.24 ,  456.926,
#           453.205,  451.924,  455.863,  451.998],
#         [ 398.098,  394.991,  396.658,  398.342,  410.796,  405.291,
#           397.497,  397.538,  397.23 ,  397.853],
#         [ 414.092,  410.71 ,  404.717,  403.293,  405.42 ,  418.669,
#           428.46 ,  411.375,  415.972,  418.068],
#         [ 422.189,  421.857,  444.17 ,  425.276,  439.676,  430.701,
#           428.114,  446.674,  437.769,  435.182],
#         [ 434.398,  435.731,  436.583,  440.191,  469.759,  440.592,
#           441.053,  440.5  ,  450.104,  458.297],
#         [ 449.949,  445.444,  458.422,  468.754,  464.317,  463.116,
#           461.064,  464.341,  465.817,  483.482]],
#
#        [[2053.415, 2026.448, 2031.374, 2051.481, 2108.973, 2088.131,
#          2074.134, 2037.583, 2037.945, 2100.353],
#         [1048.886, 1048.706, 1039.717, 1040.894, 1048.994, 1050.809,
#          1047.28 , 1045.382, 1059.732, 1039.097],
#         [ 538.493,  567.339,  592.855,  594.918,  610.333,  679.018,
#           642.011,  651.711,  660.911,  669.662],
#         [ 777.105,  717.705,  729.439,  756.83 ,  754.571,  768.859,
#           790.632,  788.991,  795.317,  814.976],
#         [ 532.032,  607.468,  592.902,  640.015,  641.629,  628.26 ,
#           625.05 ,  695.268,  632.158,  620.464],
#         [ 676.596,  728.542,  690.336,  739.224,  757.55 ,  739.055,
#           729.376,  744.668,  787.76 ,  785.657],
#         [ 875.855,  859.947,  827.459,  829.972,  925.292,  855.596,
#           907.415,  889.61 ,  931.139,  925.747],
#         [ 826.869,  871.747,  920.634,  950.469,  912.189,  961.772,
#           941.549, 1046.44 ,  933.072,  983.6  ],
#         [1020.809, 1014.366, 1041.791,  999.729,  998.673, 1081.691,
#          1026.379, 1081.232, 1021.567, 1118.162]],
#
#        [[3094.402, 2522.493, 2580.393, 2574.442, 2614.025, 2581.211,
#          2576.194, 2566.161, 2537.048, 2531.828],
#         [1472.339, 1625.798, 1661.04 , 1668.8  , 1591.212, 1623.127,
#          1605.208, 1554.641, 1554.498, 1554.116],
#         [ 959.671, 1006.975, 1079.243, 1104.186, 1115.175, 1074.339,
#          1112.32 , 1059.817, 1062.261, 1062.81 ],
#         [ 863.561,  900.813,  874.263,  868.85 ,  909.126,  860.697,
#           850.032,  878.875,  847.559,  859.086],
#         [ 774.383,  744.171,  741.634,  784.562,  767.823,  739.147,
#           786.242,  743.31 ,  735.96 ,  734.356],
#         [ 806.778,  726.27 ,  726.657,  768.255,  728.058,  746.957,
#           763.057,  723.814,  717.124,  764.173],
#         [ 724.998,  747.512,  714.161,  758.305,  726.   ,  745.527,
#           780.917,  724.334,  723.414,  724.119],
#         [ 768.936,  715.341,  755.042,  749.885,  727.097,  721.051,
#           763.993,  734.316,  746.712,  765.817],
#         [ 739.787,  723.373,  723.29 ,  796.939,  720.779,  722.744,
#           765.555,  725.847,  721.591,  760.558]]])

# %%
exec_time_list = exec_time_list * 1000.

# %%
exec_time_mean = np.mean(exec_time_list, axis=2)
exec_time_std = np.std(exec_time_list, axis=2)
exec_time_mean.shape, exec_time_std.shape
# Out:
# ((4, 9), (4, 9))

# %%
thread_list = [1,2,4,6,8,10,12,14,16]
label_list = [
    'Static with Default Chunk Size', 
    'Dynamic with Default Chunk Size', 
    'Static with Chunk Size 10', 
    'Dymamic with Chunk Size 10'
]
plt.figure(figsize=(12,8))
for sched_idx, scheduling_type in enumerate(range(1,5)):
    plt.errorbar(
        x=thread_list, 
        y=exec_time_mean[sched_idx, :], 
        yerr=exec_time_std[sched_idx, :], 
        fmt='o-',
        capsize=4,
        markersize=5,
        label=label_list[sched_idx]
    )
plt.legend()
plt.xticks(thread_list)
plt.xlabel('Number of Thread')
plt.ylabel('Execution Time $(ms)$')
plt.title('Execution Time')
# Out:
# Text(0.5, 1.0, 'Execution Time')

# %%
perf_time_list = 1. / exec_time_list
perf_time_list.shape
# Out:
# (4, 9, 10)

# %%
perf_time_mean = np.mean(perf_time_list, axis=2)
perf_time_std = np.std(perf_time_list, axis=2)
perf_time_mean.shape, perf_time_std.shape
# Out:
# ((4, 9), (4, 9))

# %%
thread_list = [1,2,4,6,8,10,12,14,16]
label_list = [
    'Static with Default Chunk Size', 
    'Dynamic with Default Chunk Size', 
    'Static with Chunk Size 10', 
    'Dymamic with Chunk Size 10'
]
plt.figure(figsize=(12,8))
for sched_idx, scheduling_type in enumerate(range(1,5)):
    plt.errorbar(
        x=thread_list, 
        y=perf_time_mean[sched_idx, :], 
        yerr=perf_time_std[sched_idx, :], 
        fmt='o-',
        capsize=4,
        markersize=5,
        label=label_list[sched_idx]
    )
plt.legend()
plt.xticks(thread_list)
plt.xlabel('Number of Thread')
plt.ylabel('Performance $(1/ms)$')
plt.title('Performance')
# Out:
# Text(0.5, 1.0, 'Performance')

# %%
exec_time_mean
# Out:
# array([[2033.6903, 1497.1466,  889.6232,  666.7727,  560.4144,  493.0341,
#          475.3363,  453.5708,  446.9308],
#        [2024.1164, 1036.7059,  538.0645,  453.6482,  399.4294,  413.0776,
#          433.1608,  444.7208,  462.4706],
#        [2060.9837, 1046.9497,  620.7251,  769.4425,  621.5246,  737.8764,
#          882.8032,  934.8341, 1040.4399],
#        [2617.8197, 1591.0779, 1063.6797,  871.2862,  755.1588,  747.1143,
#          736.9287,  744.819 ,  740.0463]])

# %%
perf_time_mean
# Out:
# array([[0.00049173, 0.00066794, 0.00112415, 0.00149999, 0.00178506,
#         0.00202896, 0.00211144, 0.00220592, 0.00224099],
#        [0.00049405, 0.0009646 , 0.00185855, 0.00220439, 0.00250389,
#         0.00242161, 0.00230949, 0.00224989, 0.00216327],
#        [0.0004853 , 0.00095519, 0.00161969, 0.00130149, 0.00161568,
#         0.00135812, 0.00113478, 0.00107369, 0.00096238],
#        [0.00038325, 0.0006293 , 0.00094197, 0.00114828, 0.00132511,
#         0.00134016, 0.00135793, 0.00134343, 0.00135271]])
